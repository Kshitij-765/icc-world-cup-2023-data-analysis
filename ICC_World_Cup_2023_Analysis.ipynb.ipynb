# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# Data cleaning and preprocessing

# %%
df=pd.read_csv("CWC2023.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Match ID          48 non-null     int64
#  1   Match Date        48 non-null     str
#  2   Match Time        48 non-null     str
#  3   City              48 non-null     str
#  4   Stadium           48 non-null     str
#  5   Team A            48 non-null     str
#  6   Team B            48 non-null     str
#  7   Toss Winner       48 non-null     str
#  8   Toss Decision     48 non-null     str
#  9   Score A           48 non-null     int64
#  10  Wickets A         48 non-null     int64
#  11  Overs Played A    48 non-null     float64
#  12  Maiden Overs A    48 non-null     int64
#  13  Boundaries A      48 non-null     int64
#  14  Runrate A         48 non-null     float64
#  15  Unnamed: 15       0 non-null      float64
#  16  Unnamed: 16       0 non-null      float64
# ...

# %%
df.isnull()
# Out:
#     Match ID  Match Date  Match Time   City  Stadium  Team A  Team B  \
# 0      False       False       False  False    False   False   False
# 1      False       False       False  False    False   False   False
# 2      False       False       False  False    False   False   False
# 3      False       False       False  False    False   False   False
# 4      False       False       False  False    False   False   False
# 5      False       False       False  False    False   False   False
# 6      False       False       False  False    False   False   False
# 7      False       False       False  False    False   False   False
# 8      False       False       False  False    False   False   False
# 9      False       False       False  False    False   False   False
# 10     False       False       False  False    False   False   False
# 11     False       False       False  False    False   False   False
# 12     False       False       False  False    False   False   False
# ...

# %%
df.isnull().sum()
# Out:
# Match ID             0
# Match Date           0
# Match Time           0
# City                 0
# Stadium              0
# Team A               0
# Team B               0
# Toss Winner          0
# Toss Decision        0
# Score A              0
# Wickets A            0
# Overs Played A       0
# Maiden Overs A       0
# Boundaries A         0
# Runrate A            0
# Unnamed: 15         48
# Unnamed: 16         48
# Unnamed: 17         48
# Unnamed: 18         48
# Extras A             0
# Score B              0
# Wickets B            0
# Overs Played B       0
# Maiden Overs B       0
# Unnamed: 24         48
# Unnamed: 25         48
# Boundaries B         0
# Runrate B            0
# Unnamed: 28         48
# Unnamed: 29         48
# Unnamed: 30         48
# Unnamed: 31         48
# Unnamed: 32         48
# Extras B             0
# Wining Team          0
# Margin               0
# Man of the Match     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Match ID', 'Match Date', 'Match Time', 'City', 'Stadium', 'Team A',
#        'Team B', 'Toss Winner', 'Toss Decision', 'Score A', 'Wickets A',
#        'Overs Played A', 'Maiden Overs A', 'Boundaries A', 'Runrate A',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Extras A',
#        'Score B', 'Wickets B', 'Overs Played B', 'Maiden Overs B',
#        'Unnamed: 24', 'Unnamed: 25', 'Boundaries B', 'Runrate B',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Extras B', 'Wining Team', 'Margin', 'Man of the Match'],
#       dtype='str')

# %%
df.drop(columns=["Unnamed: 15","Unnamed: 16","Unnamed: 17","Unnamed: 18","Unnamed: 24"], inplace=True)

# %%
df.isnull().sum()
# Out:
# Match ID             0
# Match Date           0
# Match Time           0
# City                 0
# Stadium              0
# Team A               0
# Team B               0
# Toss Winner          0
# Toss Decision        0
# Score A              0
# Wickets A            0
# Overs Played A       0
# Maiden Overs A       0
# Boundaries A         0
# Runrate A            0
# Extras A             0
# Score B              0
# Wickets B            0
# Overs Played B       0
# Maiden Overs B       0
# Unnamed: 25         48
# Boundaries B         0
# Runrate B            0
# Unnamed: 28         48
# Unnamed: 29         48
# Unnamed: 30         48
# Unnamed: 31         48
# Unnamed: 32         48
# Extras B             0
# Wining Team          0
# Margin               0
# Man of the Match     0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 25","Unnamed: 28","Unnamed: 29","Unnamed: 30","Unnamed: 31","Unnamed: 32"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Match ID          48 non-null     int64
#  1   Match Date        48 non-null     str
#  2   Match Time        48 non-null     str
#  3   City              48 non-null     str
#  4   Stadium           48 non-null     str
#  5   Team A            48 non-null     str
#  6   Team B            48 non-null     str
#  7   Toss Winner       48 non-null     str
#  8   Toss Decision     48 non-null     str
#  9   Score A           48 non-null     int64
#  10  Wickets A         48 non-null     int64
#  11  Overs Played A    48 non-null     float64
#  12  Maiden Overs A    48 non-null     int64
#  13  Boundaries A      48 non-null     int64
#  14  Runrate A         48 non-null     float64
#  15  Extras A          48 non-null     int64
#  16  Score B           48 non-null     int64
# ...

# %%
df.shape
# Out:
# (48, 26)

# %%
df.isnull().sum()
# Out:
# Match ID            0
# Match Date          0
# Match Time          0
# City                0
# Stadium             0
# Team A              0
# Team B              0
# Toss Winner         0
# Toss Decision       0
# Score A             0
# Wickets A           0
# Overs Played A      0
# Maiden Overs A      0
# Boundaries A        0
# Runrate A           0
# Extras A            0
# Score B             0
# Wickets B           0
# Overs Played B      0
# Maiden Overs B      0
# Boundaries B        0
# Runrate B           0
# Extras B            0
# Wining Team         0
# Margin              0
# Man of the Match    0
# dtype: int64

# %%
df.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023    2:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023    2:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  ...  \
# 0       England   NewZealand   NewZealand         Field      282  ...
# 1      Pakistan  Netherlands  Netherlands         Field      286  ...
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156  ...
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428  ...
# 4     Australia        India    Australia           Bat      199  ...
#
#    Score B  Wickets B  Overs Played B  Maiden Overs B  Boundaries B  \
# ...

# %%
df.tail()
# Out:
#     Match ID  Match Date Match Time       City                 Stadium  \
# 43        44  11-11-2023    2:00 PM    Kolkata            Eden Gardens
# 44        45  12-11-2023    2:00 PM  Bangalore  M. Chinnaswamy Stadium
# 45        46  15-11-2023    2:00 PM     Mumbai        Wankhede Stadium
# 46        47  16-11-2023    2:00 PM    Kolkata            Eden Gardens
# 47        48  19-11-2023    2:00 PM  Ahmedabad   Narendra Modi Stadium
#
#        Team A        Team B   Toss Winner Toss Decision  Score A  ...  \
# 43    England      Pakistan       England           Bat      244  ...
# 44      India   Netherlands         India           Bat      410  ...
# 45      India    NewZealand         India           Bat      397  ...
# 46  Australia  South Africa  South Africa           Bat      215  ...
# 47      India     Australia     Australia         Field      240  ...
#
#     Score B  Wickets B  Overs Played B  Maiden Overs B  Boundaries B  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Business questions

# %%
#Question 1: Which team has the highest number of wins in the tournament?
df["Wining Team"]
# Out:
# 0       NewZealand
# 1         Pakistan
# 2       Bangladesh
# 3     South Africa
# 4            India
# 5       NewZealand
# 6          England
# 7         Pakistan
# 8            India
# 9     South Africa
# 10      NewZealand
# 11           India
# 12     Afghanistan
# 13       Australia
# 14     Netherlands
# 15      NewZealand
# 16           India
# 17       Australia
# 18       Sri Lanka
# 19    South Africa
# 20           India
# 21     Afghanistan
# 22    South Africa
# 23       Australia
# 24       Sri Lanka
# 25    South Africa
# 26       Australia
# 27     Netherlands
# 28           India
# 29     Afghanistan
# 30        Pakistan
# 31    South Africa
# 32           India
# 33     Afghanistan
# 34        Pakistan
# 35       Australia
# 36           India
# 37      Bangladesh
# 38       Australia
# 39         England
# 40      NewZealand
# 41    South Africa
# 42       Australia
# 43         England
# 44           India
# 45           India
# 46       Australia
# ...

# %%
df.rename(columns={"Wining Team":"Winning Team"}, inplace=True)

# %%
df["Winning Team"].value_counts().head(1)
#Ans 1: India has the highes number of wins.
# Out:
# Winning Team
# India    10
# Name: count, dtype: int64

# %%
#Questions 2: Which team has won most tosses?
df["Toss Winner"].value_counts().head(1)
#Ans 2: England won the most number of tosses in the tournament.
# Out:
# Toss Winner
# England    7
# Name: count, dtype: int64

# %%
#Question 3: Which venue hosted most of the matches?
df["Stadium"].value_counts().head(1)
#Ans 3: Eden gardens
# Out:
# Stadium
# Eden Gardens    6
# Name: count, dtype: int64

# %%
#Question 4: Which team scored the highest total?
df["Score A"].sort_values(ascending=False).head(1)
# Out:
# 3    428
# Name: Score A, dtype: int64

# %%
df["Score B"].sort_values(ascending=False).head(1)
# Out:
# 26    383
# Name: Score B, dtype: int64

# %%
df.loc[df["Score A"]==428, "Team A"]
#Ans 4: South Africa scored the highest runs
# Out:
# 3    South Africa
# Name: Team A, dtype: str

# %%
#Question 5: Which team conceeded the highest runs?
#Note, we can directly get the row of the team which has scored highest total and the other team would be the ans. But by coding:
df.loc[df["Score A"]==428, "Team B"]
#Ans 5: Sri Lanka conceeded the highest runs.
# Out:
# 3    Sri Lanka
# Name: Team B, dtype: str

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#    Match ID  Match Date Match Time         City                    Stadium  \
# 0         1  05-10-2023    2:00 PM    Ahmedabad      Narendra Modi Stadium
# 1         2  06-10-2023    2:00 PM    Hyderabad               Eden Gardens
# 2         3  07-10-2023    2:00 PM  Dharamshala               HPCA Stadium
# 3         4  07-10-2023    2:00 PM        Delhi       Arun Jaitley Stadium
# 4         5  08-10-2023    2:00 PM      Chennai  M. A. Chidambaram Stadium
#
#          Team A       Team B  Toss Winner Toss Decision  Score A  Wickets A  \
# 0       England   NewZealand   NewZealand         Field      282          9
# 1      Pakistan  Netherlands  Netherlands         Field      286         10
# 2   Afghanistan   Bangladesh   Bangladesh         Field      156         10
# 3  South Africa    Sri Lanka    Sri Lanka         Field      428          5
# 4     Australia        India    Australia           Bat      199         10
#
# ...

# %%
#Question 6: Who has won highest number of man of the match award?
df["Man of the Match"].value_counts(ascending=False).head(1)
#Ans 6: Md. Shami has won highest number of man of the match award.
# Out:
# Man of the Match
# Mohammed Shami    3
# Name: count, dtype: int64

# %%
#Question 7: Which team had the highest number of boundaries in a match?
df["Boundaries A"].sort_values(ascending=False).head(1)
# Out:
# 3    59
# Name: Boundaries A, dtype: int64

# %%
df["Boundaries B"].sort_values(ascending=False).head(1)
# Out:
# 3    48
# Name: Boundaries B, dtype: int64

# %%
df.loc[df["Boundaries A"]==59, "Team A"]
#Ans 7: South Africa had the highest number of boundaries
# Out:
# 3    South Africa
# Name: Team A, dtype: str

# %%
#Question 8: Which match had the highes total score
df1=df["Score A"]+df["Score B"]
df1
# Out:
# 0     565
# 1     491
# 2     314
# 3     754
# 4     400
# 5     545
# 6     591
# 7     689
# 8     545
# 9     488
# 10    493
# 11    383
# 12    499
# 13    424
# 14    452
# 15    427
# 16    517
# 17    672
# 18    525
# 19    569
# 20    547
# 21    568
# 22    615
# 23    489
# 24    316
# 25    541
# 26    771
# 27    371
# 28    358
# 29    483
# 30    409
# 31    524
# 32    412
# 33    360
# 34    601
# 35    539
# 36    409
# 37    561
# 38    584
# 39    518
# 40    343
# 41    491
# 42    613
# 43    581
# 44    660
# 45    724
# 46    427
# 47    481
# dtype: int64

# %%
df1.sort_values(ascending=False).head(1)
# Out:
# 26    771
# dtype: int64

# %%
df.loc[26,"Match ID"]
#Ans 8: Match number 27 had the highest score, 771 runs.
# Out:
# np.int64(27)

# %%
#Question 9:Which match had the highest number of extras?
df2=df["Extras A"]+df["Extras B"]

# %%
df2.sort_values(ascending=False).head(1)
# Out:
# 18    57
# dtype: int64

# %%
df.loc[18, "Match ID"]
#Ans 9: Match number 19 had the highest number of combined extras
# Out:
# np.int64(19)

# %%
#Question 10: After winning the toss, which decision did the teams prefer more?
df["Toss Decision"].value_counts()
#Ans 10: Teams preffered fielding more, after winning the toss
# Out:
# Toss Decision
# Field    26
# Bat      22
# Name: count, dtype: int64

# %%
#Question 11: Which team faced the least overs in the tournament?
df["Overs Played A"].sort_values().head(1)
# Out:
# 33    31.3
# Name: Overs Played A, dtype: float64

# %%
df["Overs Played B"].sort_values().head(1)
# Out:
# 32    19.4
# Name: Overs Played B, dtype: float64

# %%
df.loc[32, ["Team A", "Team B", "Overs Played A", "Overs Played B"]]
#Ans 11: Sri Lanka faced the least number of overs.
# Out:
# Team A                India
# Team B            Sri Lanka
# Overs Played A         50.0
# Overs Played B         19.4
# Name: 32, dtype: object

# %%
#Question 12: What percentage of matches were won by the team that won the toss?
toss_win_won=df["Toss Winner"]==df["Winning Team"]
toss_win_won.sum()
# Out:
# np.int64(19)

# %%
p=(toss_win_won.sum()/len(df))*100
p
#Ans 12: 39.583%
# Out:
# np.float64(39.58333333333333)
